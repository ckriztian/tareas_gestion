# %% [markdown]
# ## Gestor de Tareas

# %% [markdown]
# ### Desarrollo del Programa:
# Implementar el programa en Python para gestionar tareas utilizando solo listas y diccionarios.
# Agregar al menos tres tareas distintas al programa utilizando el método insert() de la lista.
# Cada tarea debe ser representada como un diccionario con las claves nombre, descripcion y estado.Agregar al menos tres tareas distintas al programa utilizando el método insert() de la lista.

# %%
# Ejemplo de crear una lista y agregar tareas con el metodo insert.

gestor_works = []

gestor_works.insert(0,{
            "To Do": {
            "Nombre":"Comprar un auto",
            "Descripcion":"Decidir color del menú lateral",
            "Estado":"Por Hacer"
            }
        })

gestor_works.insert(1,{
            "In Progress": {
            "Nombre":"Elegir auto",
            "Descripcion":"Decidir que auto comprar entre 2 opciones",
            "Estado":"En Curso"
            }
        })

gestor_works.insert(2,{
            "Complet": {
            "Nombre":"Solicitar un prestamo",
            "Descripcion":"Solictar la mejor alternativa de prestamo bancario",
            "Estado":"Completado"
            }
        })

print(gestor_works)
# Out:
# [{'To Do': {'Nombre': 'Comprar un auto', 'Descripcion': 'Decidir color del menú lateral', 'Estado': 'Por Hacer'}}, {'In Progress': {'Nombre': 'Elegir auto', 'Descripcion': 'Decidir que auto comprar entre 2 opciones', 'Estado': 'En Curso'}}, {'Complet': {'Nombre': 'Solicitar un prestamo', 'Descripcion': 'Solictar la mejor alternativa de prestamo bancario', 'Estado': 'Completado'}}]

# %% [markdown]
# ### Eliminación de Tareas:
# Utilizar el método pop() de la lista para eliminar una de las tareas ingresadas.

# %%
eliminar_tarea = gestor_works.pop(0)

print("Se elimino la tarea: " ,eliminar_tarea)
print("Quedan las tareas: " ,gestor_works)
# Out:
# Se elimino la tarea:  {'To Do': {'Nombre': 'Comprar un auto', 'Descripcion': 'Decidir color del menú lateral', 'Estado': 'Por Hacer'}}
# Quedan las tareas:  [{'In Progress': {'Nombre': 'Elegir auto', 'Descripcion': 'Decidir que auto comprar entre 2 opciones', 'Estado': 'En Curso'}}, {'Complet': {'Nombre': 'Solicitar un prestamo', 'Descripcion': 'Solictar la mejor alternativa de prestamo bancario', 'Estado': 'Completado'}}]

# %% [markdown]
# ### Mostrar las Tareas:
# Imprimir en pantalla las tareas restantes almacenadas en la lista, accediendo directamente a los elementos mediante sus índices.

# %%
for indice in gestor_works:
    print("Resta/n la/s tarea/s: " ,indice)
# Out:
# Resta/n la/s tarea/s:  {'In Progress': {'Nombre': 'Elegir auto', 'Descripcion': 'Decidir que auto comprar entre 2 opciones', 'Estado': 'En Curso'}}
# Resta/n la/s tarea/s:  {'Complet': {'Nombre': 'Solicitar un prestamo', 'Descripcion': 'Solictar la mejor alternativa de prestamo bancario', 'Estado': 'Completado'}}
